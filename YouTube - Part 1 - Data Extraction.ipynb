# %% [markdown]
# # Part 1: Data Extraction
#
# Author: Julianne <br>
# Created: 1/28/2018<br>
# Updated: 2/26/2018<br>
#
# Step 1: Determine channels to use<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1) Extracted the top 50 most viewed category 26 videos of each month from the years 2010-2017. <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2) Determined unique channel names from previous list.<br>
#
# Step 3: Extract videos from each channel<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3) Extracted all videos from the years 2010-2017 for each channel.<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4) Shortened channel list to only include channels who have published at least 25 videos in catagory 26<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;5) Created final dataframe with all videos of the channels to be used.<br>
#
# Step 4: Extract duration for each video <br>
#
# Step 5: Extract channel information for each video<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;1) Extract channel statistics<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;2) Extract subscriber count, videoCount, viewCount<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;3) Extract playlist information for each channel<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;4) Add channel and playlist information to main dataframe<br>
#
# Step 6: Extract playlist information for each video

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %load_ext version_information
# %version_information numpy, scipy, matplotlib, pandas
# Out:
# Software versions
# Python 3.6.3 64bit [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# IPython 5.1.0
# OS Darwin 16.1.0 x86_64 i386 64bit
# numpy 1.13.3
# scipy 0.18.1
# matplotlib 2.0.0
# pandas 0.19.2
# Tue Feb 27 10:00:41 2018 EST

# %%
from __future__ import division
from datetime import datetime 
import requests
from lxml import html, etree
import json
from textblob import TextBlob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from collections import Counter
import timeit
from threading import Thread
import queue

#never print matching warnings
warnings.filterwarnings('ignore') 

#set how pandas displays data
pd.options.display.max_columns = 100
pd.options.display.max_rows = 35
pd.options.display.width = 120

#change the max # of rows pandas will display
pd.options.display.max_rows = 9000

#set to display all output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#import seaborn to draw pretty graphs
import seaborn as sns
sns.set_style('whitegrid')

#name of files
name='Youtube_Part1_cat26_byview_2017_'

# %%
# API key
#api_key = ''
api_key = ''
#api_key = ''
#api_key = '' 
#api_key = '' 
#api_key = '' 
#api_key = '' 
#api_key = '' 
#api_key = ''

# %% [markdown]
# # Step 1: Determine channels to use

# %% [markdown]
# ## 1) Determine top 50 most viewed videos of catagory 26 for each month from the years 2010-2018

# %% [markdown]
# Define functions to be used

# %%
def find_videos_cat(publishedAfter, publishedBefore, maxResults, catId):
    parameters = {'part': "snippet",
                  'type': 'video',
                  'videoCategoryId': catId,
                  'order': 'viewCount',
                  'maxResults': maxResults,
                  'publishedAfter':publishedAfter,
                  'publishedBefore':publishedBefore,
                  'key': api_key,
                  }
    url = "https://www.googleapis.com/youtube/v3/search"
    page = requests.request(method="get", url=url, params=parameters)
    j_results = json.loads(page.text)

    snippet_id=[item["snippet"]["channelId"] for item in j_results["items"]]
    snippet_channel=[item["snippet"]["channelTitle"] for item in j_results["items"]]
    id_kind=[item["id"]["kind"] for item in j_results["items"]]
    id_videoid=[item["id"]["videoId"] for item in j_results["items"]]
    snippet_title=[item["snippet"]["title"] for item in j_results["items"]]
    snippet_description=[item["snippet"]["description"] for item in j_results["items"]]
    snippet_published=[item["snippet"]["publishedAt"] for item in j_results["items"]]

    col=['dateDownloaded','videoCategoryId','channelId','channelTitle','kind','videoId','title','description','publishedAt']
    rows=len(snippet_id)
    curr_data=pd.DataFrame(columns=col, index=range(0,rows))
    curr_data['dateDownloaded']=pd.Timestamp("today").strftime("%Y-%m-%dT%H:%M:%S")
    curr_data['videoCategoryId']=catId
    curr_data['channelId']=snippet_id
    curr_data['channelTitle']=snippet_channel
    curr_data['kind']=id_kind
    curr_data['videoId']=id_videoid
    curr_data['title']=snippet_title
    curr_data['description']=snippet_description
    curr_data['publishedAt']=snippet_published
    
    return curr_data

def get_data_YYYY_MM_begin(year, month, maxResults, catId):
    start=str(year)+"-"+str(month)+"-01T00:00:00Z"
    end=str(year)+"-"+str(month)+"-15T00:00:00Z"
    return find_videos_cat(publishedAfter=start, publishedBefore=end, maxResults=maxResults, catId=catId)

def get_data_YYYY_MM_end(year, month, maxResults, catId):
    date='30'
    if month=='01' or month=='05' or month=='07' or month=='08' or month=='10' or month=='12':
        date='31'
    if month=='02':      
        date='28'
    start=str(year)+"-"+str(month)+"-16T00:00:00Z"
    end=str(year)+"-"+str(month)+"-"+str(date)+"T00:00:00Z"
    return find_videos_cat(publishedAfter=start, publishedBefore=end, maxResults=maxResults, catId=catId)

# %% [markdown]
# Run code to extract videos using YouTube's API

# %%
maxResults=50
catId=26 #category Id, 26 is for lifestyle and beauty
years=range(2012,2018)
months=['01','02','03','04','05','06','07','08','09','10','11','12']

data=get_data_YYYY_MM_begin('2017', '01', 1, 20)

#create list of tasks to be done
data_queue = queue.Queue()
for year in years:
    for month in months:
        data_queue.put([year, month])
        
# create queues to save results
results = queue.Queue()
results_empty = queue.Queue()

def threadfnc(maxResults, catId):
    while not data_queue.empty():
        
        [year, month] = data_queue.get()
        curr_begin=get_data_YYYY_MM_begin(year, month, maxResults, catId)
        curr_end=get_data_YYYY_MM_begin(year, month, maxResults, catId)
        
        if curr_begin.empty:
            print(year, month, 'empty')
        else:
            results.put(curr_begin)
        if curr_end.empty:
            print(year, month, 'empty')
        else:
            results.put(curr_end) 
            
        data_queue.task_done()
    
for i in range(20):
    t = Thread(target=threadfnc, args=(maxResults, catId))
    t.start()

data_queue.join()
    
while not results.empty():
    curr = results.get()
    data = data.append(curr, ignore_index=True)
    results.task_done()
    
data.shape[0]
data.head(2)

# %% [markdown]
# Save data

# %%
#save as csv
filename=str(name)+'step1.csv'
#data.to_csv(filename)
df=pd.read_csv(filename)
del df['Unnamed: 0']
df.head(1)
# Out:
#         dateDownloaded  videoCategoryId                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:31:48               20  UCGIY_O-8vW4rfX98KlMkvRg     Nintendo  youtube#video  5kcdRBHM7kM
#
#                                                title                                        description  \
# 0  Super Mario Odyssey - Nintendo Switch Presenta...  Super Mario Odyssey sees Mario leave the Mushr...
#
#                 publishedAt
# 0  2017-01-13T05:11:18.000Z

# %% [markdown]
# ## 2) Extract information on all videos from specified channels

# %% [markdown]
# Determine names of channels that had at least one video in at least one month in the top 50 videos.

# %%
col=['channelId','frequency']
channel_list=pd.DataFrame(df.channelId.value_counts()).reset_index()
channel_list.columns=col
channel_list=channel_list[channel_list['frequency']>=1]
channel_list=np.array(channel_list)
len(channel_list)
# Out:
# 1624

# %% [markdown]
# Next I will extract all videos from all channels of the previous list. Because API has a cap on how much data can be requested, the request must be split into multiple lists. Will use a different API for each list.

# %%
channel_list1=channel_list[0:300]
channel_list2=channel_list[300:600]
channel_list3=channel_list[600:900]
channel_list4=channel_list[900:1200]
channel_list5=channel_list[1200:1500]

# %% [markdown]
# Define functions to be used.

# %%
def find_videos(channelId, publishedAfter, publishedBefore, maxResults, vidfrequency, vidtype=26):
    parameters = {'part': 'snippet',
                  'channelId': channelId,
                  'type': "video",
                  'maxResults': maxResults,
                  'order': 'date',
                  'publishedAfter':publishedAfter,
                  'publishedBefore':publishedBefore,
                  'key': api_key,
                  }
    url = "https://www.googleapis.com/youtube/v3/search"
    col=['dateDownloaded','channelId','channelTitle','kind','videoId','title','description','publishedAt','vidfrequency','vidtype']
    curr_data=pd.DataFrame(columns=col)
    try:
        page = requests.request(method="get", url=url, params=parameters)
        j_results = json.loads(page.text)
        items = j_results.get("items", None)
        if items is None:
            return curr_data
        else:
            
            snippet_id=[item["snippet"]["channelId"] for item in j_results["items"]]
            snippet_channel=[item["snippet"]["channelTitle"] for item in j_results["items"]]
            id_kind=[item["id"]["kind"] for item in j_results["items"]]
            id_videoid=[item["id"]["videoId"] for item in j_results["items"]]
            snippet_title=[item["snippet"]["title"] for item in j_results["items"]]
            snippet_description=[item["snippet"]["description"] for item in j_results["items"]]
            snippet_published=[item["snippet"]["publishedAt"] for item in j_results["items"]]
            
            curr_data['channelId']=snippet_id
            curr_data['channelTitle']=snippet_channel
            curr_data['kind']=id_kind
            curr_data['videoId']=id_videoid
            curr_data['title']=snippet_title
            curr_data['description']=snippet_description
            curr_data['publishedAt']=snippet_published
            curr_data['vidfrequency']=vidfrequency
            curr_data['vidtype']=vidtype
            curr_data['dateDownloaded']=pd.Timestamp("today").strftime("%Y-%m-%dT%H:%M:%S")
            
            return curr_data
        
    except requests.exceptions.RequestException as e: 
        
        return curr_data

def get_data_YYYYbegin(channel_info, year, maxResults, vidtype):
    channelId=channel_info[0]
    vidfrequency=channel_info[1]
    start=str(year)+"-01-01T00:00:00Z"
    end=str(year)+"-6-30T00:00:00Z"
    return find_videos(channelId=channelId, publishedAfter=start, publishedBefore=end, maxResults=maxResults, vidfrequency=vidfrequency, vidtype=vidtype)

def get_data_YYYYend(channel_info, year, maxResults, vidtype):
    channelId=channel_info[0]
    vidfrequency=channel_info[1]
    start=str(year)+"-07-01T00:00:00Z"
    end=str(year)+"-12-31T00:00:00Z"
    return find_videos(channelId=channelId, publishedAfter=start, publishedBefore=end, maxResults=maxResults, vidfrequency=vidfrequency, vidtype=vidtype)

# %%
def extract_allvids(channel_list):
    
    maxResults=50
    vidtype=26
    years=range(2010,2018)
    
    data=get_data_YYYYbegin(channel_list[0], 2005, maxResults, vidtype)

    #create list of all tasks to be done
    data_queue = queue.Queue()
    for channel_info in channel_list:
        for year in years:
            data_queue.put((channel_info, year))

    # create queues to save results
    results = queue.Queue()

    def threadfnc(maxResults, vidtype):
        while not data_queue.empty():
            [channel_info, year] = data_queue.get()

            #get data from beginning of year
            curr_data=get_data_YYYYbegin(channel_info, year, maxResults, vidtype)
            if curr_data.empty:
                hi=5
            else:
                results.put(curr_data)

            #get data from end of year
            curr_data=get_data_YYYYend(channel_info, year, maxResults, vidtype)
            if curr_data.empty:
                hi=5
            else:
                results.put(curr_data) 
            data_queue.task_done()

    for i in range(20):
        t = Thread(target=threadfnc, args=(maxResults, vidtype))
        t.start()

    print('Step1: Extracting data')
    
    data_queue.join()
    
    print('Step2: Placing data in dataframe')

    while not results.empty():
        curr = results.get()
        data = data.append(curr, ignore_index=True)
        results.task_done()

    print('Done!')
        
    return data

# %% [markdown]
# Extract data for the specified channels. Use a different api key for each function.

# %%
tmp1=extract_allvids(channel_list1)
# Out:
# Step1: Extracting data
# Step2: Placing data in dataframe
# Done!

# %%
tmp2=extract_allvids(channel_list2)
# Out:
# Step1: Extracting data
# Step2: Placing data in dataframe
# Done!

# %%
tmp3=extract_allvids(channel_list3)
# Out:
# Step1: Extracting data
# Step2: Placing data in dataframe
# Done!

# %%
tmp4=extract_allvids(channel_list4)
# Out:
# Step1: Extracting data
# Step2: Placing data in dataframe
# Done!

# %% [markdown]
# merge the dataframes together

# %%
tmp1.shape[0]
tmp2.shape[0]
tmp3.shape[0]
tmp4.shape[0]

data=tmp1.append(tmp2).reset_index(drop=True)
data=data.append(tmp3).reset_index(drop=True)
data=data.append(tmp4).reset_index(drop=True)
data.shape[0]
# Out:
# 102441
# 73677
# 62772
# 59177
# 298067

# %%
#save as csv
filename=str(name)+'step2.csv'
#data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId   channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JrzIwYXX4lw
# 1  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JEI0m85O1gE
#
#                                         title                                        description  \
# 0  GORILLA GYM - DOES THIS THING REALLY WORK?  NEW SWAMP FAMILY STORE- http://www.swampmerch....
# 1       BLOTTERAZZI - FIRST IMPRESSION FRIDAY  NEW SWAMP FAMILY STORE- http://www.swampmerch....
#
#                 publishedAt  vidfrequency  vidtype
# 0  2015-06-27T20:03:01.000Z           117       26
# 1  2015-06-26T22:18:37.000Z           117       26

# %% [markdown]
# ## 3) Extract catagory ID for each video

# %%
def get_video_snippet(video_id):
    parameters = {"part": "snippet",
              "id": video_id,
              "key": api_key
              }
    url = "https://www.googleapis.com/youtube/v3/videos"
    col=['videoId','categoryId']
    df=pd.DataFrame(columns=col,index=range(1))
    try:
        page = requests.request(method="get", url=url, params=parameters)
        j_results = json.loads(page.text)
        items = j_results.get("items", None)
        if items is None:
            return df
        else:
            if len(items)>0:
                df['videoId']=video_id
                sublist=items[0]
                if 'categoryId' in sublist['snippet']:
                    df['categoryId']=[item["snippet"]["categoryId"] for item in j_results["items"]][0]
                return df
            else:
                return df
    except requests.exceptions.RequestException as e: 
        return df

# %%
# data to work on
data=data

#create queue of all tasks to be done
data_queue = queue.Queue()
curr_list=list(data['videoId'])
for i in range(len(curr_list)):
    data_queue.put(curr_list[i])
    
# create queues to save results
results = queue.Queue()

def threadfnc():
    while not data_queue.empty():
        video_id = data_queue.get()
        df=get_video_snippet(video_id)
        results.put(df)
        data_queue.task_done()
        
for i in range(50):
    t = Thread(target=threadfnc, args=())
    t.start()

data_queue.join()

col=['videoId','categoryId']
df=pd.DataFrame(columns=col,index=range(0))

while not results.empty():
    curr = results.get()
    df = df.append(curr, ignore_index=True)
    results.task_done()

df.head(2)
    
data = pd.merge(data, df, on=['videoId'])
data.head(2)
# Out:
#        videoId categoryId
# 0  JrzIwYXX4lw         26
# 1  JEI0m85O1gE         26
#         dateDownloaded                 channelId   channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JrzIwYXX4lw
# 1  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JEI0m85O1gE
#
#                                         title                                        description  \
# 0  GORILLA GYM - DOES THIS THING REALLY WORK?  NEW SWAMP FAMILY STORE- http://www.swampmerch....
# 1       BLOTTERAZZI - FIRST IMPRESSION FRIDAY  NEW SWAMP FAMILY STORE- http://www.swampmerch....
#
#                 publishedAt  vidfrequency  vidtype categoryId
# 0  2015-06-27T20:03:01.000Z           117       26         26
# 1  2015-06-26T22:18:37.000Z           117       26         26

# %%
### save as csv
filename=str(name)+'step3.csv'
data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId   channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JrzIwYXX4lw
# 1  2018-02-26T12:48:50  UCGwPbAQdGA3_88WBuGtg9tw  grav3yardgirl  youtube#video  JEI0m85O1gE
#
#                                         title                                        description  \
# 0  GORILLA GYM - DOES THIS THING REALLY WORK?  NEW SWAMP FAMILY STORE- http://www.swampmerch....
# 1       BLOTTERAZZI - FIRST IMPRESSION FRIDAY  NEW SWAMP FAMILY STORE- http://www.swampmerch....
#
#                 publishedAt  vidfrequency  vidtype  categoryId
# 0  2015-06-27T20:03:01.000Z           117       26          26
# 1  2015-06-26T22:18:37.000Z           117       26          26

# %% [markdown]
# ## 4) Drop channels with fewer than 25 videos in catagory 26
# Because of limits with the YouTube API, I cannot keep all channels. By dropping channels with fewer than 25 vidoes in catagory 26, I will have a small enough dataset to extract channel information more easily.

# %%
channels=pd.DataFrame(data.groupby(['channelTitle', 'categoryId']).agg('count')).reset_index()
channels=channels[channels['categoryId']==26].reset_index()
channels=channels[channels['dateDownloaded']>25].reset_index()
channels=channels[0:700]
channels['meetscriteria']='yes'
channels
# Out:
#      level_0  index                                       channelTitle  categoryId  dateDownloaded  channelId  kind  \
# 0          0      3                            (Accidentally) Vegan TV          26              99         99    99
# 581       26     26           26           26            26       26           yes
# 582      138    138          138          138           138      138           yes
# 583       67     67           67           67            67       67           yes
# 584      324    324          324          324           324      324           yes
# 585      644    644          644          644           644      644           yes
# 586      609    609          609          609           609      609           yes
# 587      254    254          254          254           254      254           yes
# 588      226    226          226          226           226      226           yes
# 589      386    386          386          386           386      386           yes
# 590      283    283          283          283           283      283           yes
# 591      157    157          157          157           157      157           yes
# 592      571    571          524          571           571      571           yes
# 593       52     52           52           52            52       52           yes
# 594      231    231          231          231           231      231           yes
# 595       73     73           73           73            73       73           yes
# 596       61     61           61           61            61       61           yes
# 597      211    211          211          211           211      211           yes
# 598      185    185          185          185           185      185           yes
# 599       52     52           52           52            52       52           yes
# 600      118    118          117          118           118      118           yes
# 601      422    422          422          422           422      422           yes
# 602      392    392          390          392           392      392           yes
# 603       50     50           50           50            50       50           yes
# 604      139    139          139          139           139      139           yes
# 605       98     98           98           98            98       98           yes
# 606       38     38           38           38            38       38           yes
# 607      329    329          329          329           329      329           yes
# 608      224    224          224          224           224      224           yes
# 609       30     30           30           30            30       30           yes
# 610      100    100          100          100           100      100           yes
# 611       26     26           26           26            26       26           yes
# 612       63     63           62           63            63       63           yes
# 613      323    323          323          323           323      323           yes
# 614       50     50           50           50            50       50           yes
# 615      754    754          750          754           754      754           yes
# 616       51     51           51           51            51       51           yes
# 617      444    444          444          444           444      444           yes
# 618      310    310          310          310           310      310           yes
# 619       76     76           75           76            76       76           yes
# 620      400    400          400          400           400      400           yes
# 621      189    189          189          189           189      189           yes
# 622      276    276          276          276           276      276           yes
# 623      155    155          155          155           155      155           yes
# 624      247    247          247          247           247      247           yes
# 625      386    386          385          386           386      386           yes
# 626      411    411          411          411           411      411           yes
# 627      219    219          191          219           219      219           yes
# 628      107    107          107          107           107      107           yes
# 629       43     43           43           43            43       43           yes
# 630      576    576          576          576           576      576           yes
# 631      419    419          419          419           419      419           yes
# 632      255    255          255          255           255      255           yes
# 633      282    282          276          282           282      282           yes
# 634      101    101          101          101           101      101           yes
# 635      333    333          333          333           333      333           yes
# 636      106    106          106          106           106      106           yes
# 637      213    213          208          213           213      213           yes
# 638      489    489          489          489           489      489           yes
# 639      323    323          323          323           323      323           yes
# 640      270    270          270          270           270      270           yes
# 641      450    450          450          450           450      450           yes
# 642      741    741          741          741           741      741           yes
# 643      148    148          148          148           148      148           yes
# 644      431    431          431          431           431      431           yes
# 645      108    108          108          108           108      108           yes
# 646       50     50           37           50            50       50           yes
# 647      240    240          240          240           240      240           yes
# 648       59     59           59           59            59       59           yes
# 649       29     29           29           29            29       29           yes
# 650       99     99           99           99            99       99           yes
# 651       48     48           48           48            48       48           yes
# 652      503    503          501          503           503      503           yes
# 653      505    505          504          505           505      505           yes
# 654      719    719          719          719           719      719           yes
# 655      473    473          473          473           473      473           yes
# 656       44     44           44           44            44       44           yes
# 657       95     95           95           95            95       95           yes
# 658      197    197          197          197           197      197           yes
# 659       60     60           60           60            60       60           yes
# 660       95     95           95           95            95       95           yes
# 661       96     96           96           96            96       96           yes
# 662       58     58           54           58            58       58           yes
# 663       98     98           98           98            98       98           yes
# 664       76     76           76           76            76       76           yes
# 665      366    366          366          366           366      366           yes
# 666      781    781          781          781           781      781           yes
# 667      207    207          207          207           207      207           yes
# 668      116    116          116          116           116      116           yes
# 669      275    275          275          275           275      275           yes
# 670       28     28           28           28            28       28           yes
# 671       43     43           43           43            43       43           yes
# 672      264    264          263          264           264      264           yes
# 673      271    271          270          271           271      271           yes
# 674       91     91           91           91            91       91           yes
# 675      482    482          482          482           482      482           yes
# 676      211    211          211          211           211      211           yes
# 677      185    185          185          185           185      185           yes
# 678      275    275          274          275           275      275           yes
# 679       27     27           27           27            27       27           yes
# 680      101    101          101          101           101      101           yes
# 681      275    275          275          275           275      275           yes
# 682      307    307          307          307           307      307           yes
# 683      256    256          256          256           256      256           yes
# 684       81     81           81           81            81       81           yes
# 685      706    706          706          706           706      706           yes
# 686      329    329          329          329           329      329           yes
# 687      501    501          500          501           501      501           yes
# 688      167    167          167          167           167      167           yes
# 689      180    180          180          180           180      180           yes
# 690       84     84           82           84            84       84           yes
# 691      608    608          608          608           608      608           yes
# 692      155    155          155          155           155      155           yes
# 693      136    136          136          136           136      136           yes
# 694       31     31           31           31            31       31           yes
# 695      423    423          423          423           423      423           yes
# 696      424    424          424          424           424      424           yes
# 697       45     45           45           45            45       45           yes
# 698       79     79           79           79            79       79           yes
# 699       85     85           85           85            85       85           yes

# %%
channels=channels[['channelTitle','meetscriteria']]
channels.head(2)
# Out:
#               channelTitle meetscriteria
# 0  (Accidentally) Vegan TV           yes
# 1              *Owen Video           yes

# %%
data = pd.merge(data, channels, how='left', on='channelTitle')
data = data[data['meetscriteria']=='yes']
del data['meetscriteria']
data.shape[0]
data.head(2)
# Out:
# 194133
#           dateDownloaded                 channelId channelTitle           kind      videoId  \
# 196  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 197  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                              title                                        description  \
# 196  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 197          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                   publishedAt  vidfrequency  vidtype  categoryId
# 196  2017-06-29T17:00:02.000Z           110       26          26
# 197  2017-06-29T11:00:05.000Z           110       26          26

# %%
#save as csv
filename=str(name)+'step4.csv'
data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId
# 0  2017-06-29T17:00:02.000Z           110       26          26
# 1  2017-06-29T11:00:05.000Z           110       26          26

# %% [markdown]
# # Step 2: Extract duration for each video

# %%
def get_video_duration(video_id):
    parameters = {"part": "contentDetails",
              "id": video_id,
              "key": api_key
              }
    url = "https://www.googleapis.com/youtube/v3/videos"
    try:
        page = requests.request(method="get", url=url, params=parameters)
        j_results = json.loads(page.text)
        items = j_results.get("items", None)
        if items is None:
            return 'NA'
        else:
            if len(items)>0:
                sublist=items[0]
                if 'duration' in sublist['contentDetails']:
                    return [item["contentDetails"]["duration"] for item in j_results["items"]][0]
                else:
                    return 'NA'
            else:
                return 'NA'
    except requests.exceptions.RequestException as e: 
        return -1

# %%
#data to work on
data=data

#create queue of all tasks to be done
data_queue = queue.Queue()
curr_list=list(data['videoId'])
for i in range(len(curr_list)):
    data_queue.put(curr_list[i])
    
# create queues to save results
results = queue.Queue()

def threadfnc():
    while not data_queue.empty():
        video_id = data_queue.get()
        curr_data=get_video_duration(video_id)
        results.put([video_id,curr_data])
        data_queue.task_done()
        
for i in range(30):
    t = Thread(target=threadfnc, args=())
    t.start()

data_queue.join()

col=['videoId','videoDuration']
curr_data=pd.DataFrame(columns=col)
while not results.empty():
    curr = results.get()
    curr=pd.DataFrame([curr], columns=col)
    curr_data = curr_data.append(curr, ignore_index=True)
    results.task_done()

curr_data.head(2)
    
data = pd.merge(data, curr_data, on=['videoId'])
data.head(2)
# Out:
#        videoId videoDuration
# 0  axhPJi626SM       PT5M19S
# 1  v4rNOLZgKF4       PT8M11S
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S

# %%
#save as csv
filename=str(name)+'step5.csv'
data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-26T12:48:50  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S

# %% [markdown]
# # Step 3: Add statistics for each video

# %%
def get_video_statistics(video_id):
    parameters = {"part": "statistics",
              "id": video_id,
              "key": api_key
              }
    url = "https://www.googleapis.com/youtube/v3/videos"
    col=['videoId','commentCount','dislikeCount','likeCount','viewCount']
    df=pd.DataFrame(columns=col,index=range(1))
    try:
        page = requests.request(method="get", url=url, params=parameters)
        j_results = json.loads(page.text)
        items = j_results.get("items", None)
        if items is None:
            return df
        else:
            if len(items)>0:
                df['videoId']=[item["id"] for item in j_results["items"]][0]
                sublist=items[0]
                if 'commentCount' in sublist['statistics']:
                    df['commentCount']=[item["statistics"]["commentCount"] for item in j_results["items"]][0]
                if 'dislikeCount' in sublist['statistics']:
                    df['dislikeCount']=[item["statistics"]["dislikeCount"] for item in j_results["items"]][0]
                if 'likeCount' in sublist['statistics']:
                    df['likeCount']=[item["statistics"]["likeCount"] for item in j_results["items"]][0]
                if 'viewCount' in sublist['statistics']:
                    df['viewCount']=[item["statistics"]["viewCount"] for item in j_results["items"]][0]
                return df
            else:
                return df
    except requests.exceptions.RequestException as e: 
        return df

# %%
# data to work on
data=data

#create queue of all tasks to be done
data_queue = queue.Queue()
curr_list=list(data['videoId'])
for i in range(len(curr_list)):
    data_queue.put(curr_list[i])
    
# create queues to save results
results = queue.Queue()

def threadfnc():
    while not data_queue.empty():
        video_id = data_queue.get()
        df=get_video_statistics(video_id)
        results.put(df)
        data_queue.task_done()
        
for i in range(20):
    t = Thread(target=threadfnc, args=())
    t.start()

print('Part 1')    

data_queue.join()

print('Part 2')

col=['videoId','commentCount','dislikeCount','likeCount','viewCount']
df=pd.DataFrame(columns=col,index=range(0))

while not results.empty():
    curr = results.get()
    df = df.append(curr, ignore_index=True)
    results.task_done()

df.head(2)
    
data = pd.merge(data, df, on=['videoId'])
data.head(2)
# Out:
# Part 1
# Part 2
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount
# 0   243100.0
# 1    38640.0

# %%
#save as csv
filename=str(name)+'step6.csv'
#data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount
# 0   243100.0
# 1    38640.0

# %% [markdown]
# # Step 4: Extract channel-related information

# %% [markdown]
# ## 1) Extract channel statistics

# %%
#create small dataframe with channel information
channels=data.channelId.unique()
col=['dateDownloaded','channelTitle','channelId']
rows=len(channels)
df_channels=pd.DataFrame(columns=col,index=range(0,rows))
for i in range(0,rows):
    df_channels['dateDownloaded'][i]=pd.Timestamp("today").strftime("%Y-%m-%dT%H:%M:%S")
    df_channels['channelTitle'][i]=np.array(data[data['channelId']==channels[i]].channelTitle)[0]
    df_channels['channelId'][i]=channels[i]
df_channels.head(2)
# Out:
#         dateDownloaded channelTitle                 channelId
# 0  2018-02-25T17:13:50  BRIGHT SIDE  UC4rlAVgAK0SGk-yTfe48Qpw
# 1  2018-02-25T17:13:50   ATHLEAN-X™  UCe0TLA0EsQbE-MjuHXevj2A

# %% [markdown]
# ## 2) Extract subscriber count, videoCount, viewCount

# %%
df_channels['commentCount']='NA'
df_channels['hiddenSubscriberCount']='NA'
df_channels['subscriberCount']='NA'
df_channels['videoCount']='NA'
df_channels['viewCount']='NA'

for i in range(0,df_channels.shape[0]):
    curr_channel=df_channels.channelId[i]
    parameters = {"part": "statistics",
          "id": curr_channel,
          "key": api_key
          }
    url = "https://www.googleapis.com/youtube/v3/channels"
    page = requests.request(method="get", url=url, params=parameters)
    j_results = json.loads(page.text)
    df_channels["commentCount"][i] = [item["statistics"]["commentCount"] for item in j_results["items"]][0]
    df_channels["hiddenSubscriberCount"][i] = [item["statistics"]["hiddenSubscriberCount"] for item in j_results["items"]][0]
    df_channels["subscriberCount"][i] = [item["statistics"]["subscriberCount"] for item in j_results["items"]][0]
    df_channels["videoCount"][i] = [item["statistics"]["videoCount"] for item in j_results["items"]][0]
    df_channels["viewCount"][i] = [item["statistics"]["viewCount"] for item in j_results["items"]][0]
df_channels.head(2)
# Out:
#         dateDownloaded channelTitle                 channelId commentCount hiddenSubscriberCount subscriberCount  \
# 0  2018-02-25T17:13:50  BRIGHT SIDE  UC4rlAVgAK0SGk-yTfe48Qpw            0                 False         7860308
# 1  2018-02-25T17:13:50   ATHLEAN-X™  UCe0TLA0EsQbE-MjuHXevj2A         3650                 False         4612450
#
#   videoCount   viewCount
# 0        894  1523479095
# 1        888   665880213

# %%
#save as csv
#df_channels.to_csv('Youtube_cat26_byDate_channelInfo.csv')
#df_channels=pd.read_csv('Youtube_cat26_byDate_channelInfo.csv')
#del df_channels['Unnamed: 0']
df_channels.head(2)
# Out:
#         dateDownloaded channelTitle                 channelId commentCount hiddenSubscriberCount subscriberCount  \
# 0  2018-02-25T17:13:50  BRIGHT SIDE  UC4rlAVgAK0SGk-yTfe48Qpw            0                 False         7860308
# 1  2018-02-25T17:13:50   ATHLEAN-X™  UCe0TLA0EsQbE-MjuHXevj2A         3650                 False         4612450
#
#   videoCount   viewCount
# 0        894  1523479095
# 1        888   665880213

# %% [markdown]
# ## 3) Extract playlist information for each channel

# %% [markdown]
# Extract a list of all playlistIds for each channel in df_channels.

# %%
col=['id', 'kind', 'channelId', 'channelTitle', 'description', 'title', 'publishedAt']
playlist_df=pd.DataFrame(columns=col)
for channel in list(df_channels.channelId):
    parameters = {"part": "snippet",
                  "channelId": channel,
                  'maxResults': 50,
                  "key": api_key
                  }
    url = "https://www.googleapis.com/youtube/v3/playlists"
    page = requests.request(method="get", url=url, params=parameters)
    j_results = json.loads(page.text)
    
    ids=[item["id"] for item in j_results["items"]]
    kinds=[item["kind"] for item in j_results["items"]]
    channelIds=[item["snippet"]['channelId'] for item in j_results["items"]]
    channelTitles=[item["snippet"]['channelTitle'] for item in j_results["items"]]
    desc=[item["snippet"]['description'] for item in j_results["items"]]
    title=[item["snippet"]['title'] for item in j_results["items"]]
    publishedAts=[item["snippet"]['publishedAt'] for item in j_results["items"]]
    
    curr_df=pd.DataFrame(columns=col, index=range(0,len(ids)))
    curr_df['id']=ids
    curr_df['kind']=kinds
    curr_df['channelId']=channelIds
    curr_df['channelTitle']=channelTitles
    curr_df['description']=desc
    curr_df['title']=title
    curr_df['publishedAt']=publishedAts
    
    playlist_df=playlist_df.append(curr_df, ignore_index=True) ## need to use ignore_index=True in order to make new index

playlist_df.head(2)
# Out:
#                                    id              kind                 channelId channelTitle  \
# 0  PLVNocu2A1SADjisuByJd3zA_EUA7cqKl-  youtube#playlist  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE
# 1  PLVNocu2A1SAAgwy9JSXM7k3IoKiuqsTQx  youtube#playlist  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE
#
#                                          description       title               publishedAt
# 0                                                     Life Hacks  2018-02-05T13:29:38.000Z
# 1  Amazing facts about human body you've probably...  Human Body  2018-01-21T10:38:49.000Z

# %% [markdown]
# Add the number of playlists for each channel in df_channels,

# %%
# determine how many playlists per channel
df_channels['num_of_playlists']=0
row=-1
for i in range(df_channels.shape[0]):
    row=row+1
    channel=df_channels['channelTitle'][row]
    currdf=playlist_df[playlist_df['channelTitle']==channel]
    df_channels['num_of_playlists'][row]=currdf.shape[0]
df_channels.head(2)
# Out:
#         dateDownloaded channelTitle                 channelId commentCount hiddenSubscriberCount subscriberCount  \
# 0  2018-02-25T17:13:50  BRIGHT SIDE  UC4rlAVgAK0SGk-yTfe48Qpw            0                 False         7860308
# 1  2018-02-25T17:13:50   ATHLEAN-X™  UCe0TLA0EsQbE-MjuHXevj2A         3650                 False         4612450
#
#   videoCount   viewCount  num_of_playlists
# 0        894  1523479095                17
# 1        888   665880213                21

# %%
#save as csv
playlist_df.to_csv('Youtube_Part1_cat26_byView_playlistInfo.csv')
playlist_df=pd.read_csv('Youtube_Part1_cat26_byView_playlistInfo.csv')
del playlist_df['Unnamed: 0']
playlist_df.head(2)
# Out:
#                                    id              kind                 channelId channelTitle  \
# 0  PLVNocu2A1SADjisuByJd3zA_EUA7cqKl-  youtube#playlist  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE
# 1  PLVNocu2A1SAAgwy9JSXM7k3IoKiuqsTQx  youtube#playlist  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE
#
#                                          description       title               publishedAt
# 0                                                     Life Hacks  2018-02-05T13:29:38.000Z
# 1  Amazing facts about human body you've probably...  Human Body  2018-01-21T10:38:49.000Z

# %% [markdown]
# ## 4) Add channel and playlist information to main dataframe

# %%
#select columns
subdf=df_channels.loc[:,['channelId','commentCount','hiddenSubscriberCount','subscriberCount','videoCount','viewCount','num_of_playlists']]

#rename columns
subdf.columns=['channelId','stats_commentCount','stats_hiddenSubscriberCount','stats_subscriberCount','stats_videoCount','stats_viewCount','num_of_playlists']
subdf.head(2)

#merge dataframes
data = pd.merge(data, subdf, on=['channelId'])
data.head(2)
# Out:
#                   channelId stats_commentCount stats_hiddenSubscriberCount stats_subscriberCount stats_videoCount  \
# 0  UC4rlAVgAK0SGk-yTfe48Qpw                  0                       False               7860308              894
# 1  UCe0TLA0EsQbE-MjuHXevj2A               3650                       False               4612450              888
#
#   stats_viewCount  num_of_playlists
# 0      1523479095                17
# 1       665880213                21
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount stats_commentCount stats_hiddenSubscriberCount stats_subscriberCount stats_videoCount stats_viewCount  \
# 0   243100.0                  0                       False               7860308              894      1523479095
# 1    38640.0                  0                       False               7860308              894      1523479095
#
#    num_of_playlists
# 0                17
# 1                17

# %%
#save as csv
filename=str(name)+'step10.csv'
data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount  stats_commentCount stats_hiddenSubscriberCount  stats_subscriberCount  stats_videoCount  \
# 0   243100.0                   0                       False                7860308               894
# 1    38640.0                   0                       False                7860308               894
#
#    stats_viewCount  num_of_playlists
# 0       1523479095                17
# 1       1523479095                17

# %% [markdown]
# # Step 5: Determine if video is in a playlist or not

# %% [markdown]
# Create dataframe with all videos in the playlists

# %%
def get_video_playlist(playlist):
    
    parameters = {"part": "snippet",
                  "playlistId": playlist,
                  'maxResults': 50,
                  "key": api_key
                  }
    url = "https://www.googleapis.com/youtube/v3/playlistItems"
    col=['playlistId', 'position' , 'videoId']
    df=pd.DataFrame(columns=col)
    try:
        page = requests.request(method="get", url=url, params=parameters)
        j_results = json.loads(page.text)
        items = j_results.get("items", None)
        if items is None:
            return df
        else: 
            if len(items)>0:
                sublist=items[0]   
                if 'playlistId' in sublist['snippet']:
                    df['playlistId']=[item["snippet"]["playlistId"] for item in j_results["items"]]
                if 'position' in sublist['snippet']:
                    df['position']=[item["snippet"]["position"] for item in j_results["items"]]
                    df['videoId']=[item["snippet"]["resourceId"]['videoId'] for item in j_results["items"]]
                return df
            else:
                return df
    except requests.exceptions.RequestException as e: 
        return df

# %%
# data to work on
playlist_df=playlist_df

#create queue of all tasks to be done
data_queue = queue.Queue()
curr_list=list(playlist_df['id'])
for i in range(len(curr_list)):
    data_queue.put(curr_list[i])
    
# create queues to save results
results = queue.Queue()

def threadfnc():
    while not data_queue.empty():
        playlist = data_queue.get()
        df=get_video_playlist(playlist)
        results.put(df)
        data_queue.task_done()
        
for i in range(100):
    t = Thread(target=threadfnc, args=())
    t.start()

data_queue.join()

col=['playlistId', 'position' , 'videoId']
df=pd.DataFrame(columns=col,index=range(0))

while not results.empty():
    curr = results.get()
    df = df.append(curr, ignore_index=True)
    results.task_done()

df.head(2)
# Out:
#                            playlistId  position      videoId
# 0  PLVNocu2A1SADjisuByJd3zA_EUA7cqKl-       0.0  gUppezqI3yc
# 1  PLVNocu2A1SADjisuByJd3zA_EUA7cqKl-       1.0  AVSCjxSqK2Q

# %% [markdown]
# Count number of playlists that each video was included in

# %%
col=['videoId','num_of_playlists_forvid']
videoId_list=pd.DataFrame(df.videoId.value_counts()).reset_index()
videoId_list.columns=col
videoId_list
# Out:
#             videoId  num_of_playlists_forvid
# 0       wtPvhIocZxs                       40
# 1       ZlTRurKVYJE                       39
# 2       IMNOnqUm_Jc                       39
# 3       5QttvrmtcfQ                       38
# 4       xomVeuB2Ld4                       31
# 5       huX0Dn3RZJE                       28
# 6       Vuxnvk96Igg                       22
# 7       148n-j5MBPg                       22
# 8       eDaLxaeArt4                       21
# 9       KKydUVdsuLI                       21
# 10      sxb3sUPh5RY                       20
# 11      a5e2XsHbPYY                       19
# 12      0n0U8crkhKs                       19
# 13      12UJvz0f-8k                       19
# 14      -_NxIxHNI3A                       19
# 15      6hKwmJWCnQY                       19
# 16      bHglySrR5vs                       19
# 17      kS-p2NOrEmI                       19
# 18      jT8yswXdxFk                       18
# 19      eb6EcVcrcbM                       18
# 20      TNIWThwlRwU                       18
# 21      fxOd6EJZi64                       18
# 22      aqSyEikq1JQ                       18
# 23      uUB95RWKVj8                       17
# 24      IIuHoRN1Izc                       17
# 25      qhuRw88A-8c                       17
# 26      6Q80jyNnCAo                       17
# 27      WFAu6NKPXXw                       17
# 28      Qu0f1wKOwlI                       17
# 29      fSMwBpOlBek                       16
# 30      GomG4V9qVGk                       16
# 31      LKhHkoP27wY                       16
# 32      AohN7A86SDQ                       16
# 33      DpChBVRq8nE                       16
# 34      MUDbLfTVSbk                       16
# 35      GdZiesdZXbA                       16
# 36      rW-subWDZNQ                       16
# 37      uXKDy_BgdL0                       16
# 38      FicRiQn3PPE                       16
# 39      7I0JgHFTrQw                       16
# 40      DhedUcDUnOE                       15
# 41      -ALfyH0_rk4                       15
# 42      3DRfsjyCPXM                       15
# 43      diccQNXiIDc                       15
# 44      ixQ62SqK7L8                       15
# 45      d9vdeIhpXDo                       14
# 46      krKXXmnLQ80                       14
# 47      sk4OyEKrfds                       14
# 48      uqxN9mDpSqI                       14
# 49      hyhV614RDwA                       14
# 50      Xdz4igyBKEU                       14
# 51      a265vozzR9I                       14
# 52      SF1VxPanNdA                       14
# 53      JeYP5sySvJs                       14
# 54      2lWyjJ6FZyo                       14
# 55      2dnWvnXdYWA                       14
# 56      NE7JHzH0iQU                       14
# 57      WUAv5KGJxvg                       13
# 58      bXWsIXSWnhg                       13
# 59      FCCq6thzWIw                       13
# 60      CKBKv2fyOiQ                       13
# 61      PQ4IWsjrpCk                       13
# 62      TDPZiARxgQU                       13
# 63      YureB2EMzn8                       13
# 64      d-XRUnnwtyE                       13
# 65      RKWjGaJ0Piw                       13
# 66      3p1rLYE9zpQ                       13
# 67      22ZBdbfHPQ4                       13
# 68      odtn3QxWl7Q                       12
# 69      waBZwPO-F58                       12
# 70      zlCQ5-C1LNU                       12
# 71      6odItDlW8zI                       12
# 72      PwZLnHOjUqo                       12
# 73      nF1lWCf2NjY                       12
# 74      xfgZyKcSZ6E                       12
# 75      -p3mkhHapmg                       12
# 76      AZ4wDE1OOx4                       12
# 77      LZz0rHCP8VE                       12
# 78      CNJEWq5e7Os                       12
# 79      _krHjYqhUg8                       12
# 80      nnNYlEKE2EA                       12
# 81      TxXkBhZHoLQ                       12
# 82      Yev8DaSOSkA                       12
# 83      EoC83JhkCAw                       12
# 84      QsiImYTLvTk                       12
# 85      9VLtlm9dGqg                       12
# 86      aWULjvxaMxo                       12
# 87      m5rq94KsKa8                       11
# 88      naPzdwrP3_A                       11
# 89      p-dZiNRpoak                       11
# 90      KSiTBqOaA-c                       11
# 91      E4f9nVG-V20                       11
# 92      bO9r-xXXYqw                       11
# 93      Bq5EXH1X94k                       11
# 94      -0_8Y-wOwPI                       11
# 95      NQms_Vt4jlg                       11
# 96      U1EwseCdCxk                       11
# 97      Wig6vxK0kl8                       11
# 98      umh2BLB27O4                       11
# 99      mvvpNSaYGSs                       11
# 100     F-qfVivF2eA                       11
# 101     XFITHayq0gg                       11
# 102     BvcF4pPGrUI                       11
# 103     7vlfSg_2fec                       11
# 104     fwGU4Kgig3c                       11
# 105     3DXLAtPnVYs                       11
# 106     K82EMhxrxsg                       11
# 107     _Yi4GrML2RE                       11
# 108     X7Vd_XtQoMM                       11
# 109     _lqGYOuzVjg                       11
# 110     yFG_dPu7mGo                       11
# 111     RDQmnzuE2q4                       10
# 112     YqncE3oZUX0                       10
# 113     d22KWVJl3lo                       10
# 114     0GHVF6mJ0sU                       10
# 115     X3nEMYW4gAg                       10
# 116     rWd8rK-RlT4                       10
# 117     ZilxvFMsuTw                       10
# 118     y0cE7M5jgkE                       10
# 119     jr2sLOA3ydY                       10
# 120     CHZEN7Ilqdk                       10
# 121     WisXobXI6I0                       10
# 122     KAMaomvoRlI                       10
# 123     3P9W07qfI30                       10
# 124     usnaufizbmo                       10
# 125     Pl2rEl3XOhk                       10
# 126     i91_6CJFxEg                       10
# 127     DEySt9IPtsc                       10
# 128     IJro-Hd9wK4                       10
# 129     8RiReM1DmPI                       10
# 130     eXwHHDPg_I0                       10
# 131     WiKhMQSCvjE                       10
# 132     Nuqs5nWA5Sw                       10
# 133     IPoeyOjq7E0                       10
# 134     vE8AGHB7kxU                       10
# 135     FBpvbqHKgr8                       10
# 136     R_aMIV86fek                       10
# 137     M9a6JKtFEOo                       10
# 138     Qu5_zQ4-9Vw                       10
# 139     LtKC-2bFbMw                       10
# 140     WlFGnh08n1c                       10
# 141     IEL7pLwTZw0                       10
# 142     Czve2yXJPig                       10
# 143     3lJjg87g55Q                       10
# 144     CEr0BvXen5Q                       10
# 145     ulW0qieaVlI                       10
# 146     2bEddGfthw8                       10
# 147     deFH7kPBFQg                       10
# 148     XyRndu-_t0k                       10
# 149     1g-JGA81qpA                       10
# 150     ioHzIBhXe5o                       10
# 151     Q5N06FkqXgg                       10
# 152     eFCq_Zd5BJ0                       10
# 153     sJuCeYtYvk0                       10
# 154     l43fu4S_Lu0                       10
# 155     eL8--AXlsuo                       10
# 156     hjOHc4vEzuc                       10
# 157     RT8iRlCgBRY                       10
# 158     HNxuq0yTZTg                       10
# 159     dM5tJgvOgv0                       10
# 160     rtZqkV3DVRs                       10
# 161     I-AtvVCydD0                       10
# 162     _nlUMQR5jT0                        9
# 163     K4liVOUL5N4                        9
# 164     EM-dIvXAHlM                        9
# 165     UcIZZYqWuaU                        9
# 166     VbtxWL1shWk                        9
# 167     K4vGooYEwkA                        9
# 168     TQu2uKClXZ4                        9
# 169     G3GZfU0G9D0                        9
# 170     rZxij0C5js8                        9
# 171     75m80pfTrvg                        9
# 172     AVmgQfh_avs                        9
# 173     WczWakYw2cM                        9
# 174     K0P-PxeS4Cc                        9
# 175     8GT1vItZ6xQ                        9
# 176     Ur_Rgsj5hh0                        9
# 177     k7EVFW1nCNI                        9
# 178     W64HJASay5g                        9
# 179     aSRz2YZwpOM                        9
# 180     TIixEE86SD0                        9
# 181     4CeH7uop89A                        9
# 182     tW78iVjXatk                        9
# 183     3jkGJAcmXxw                        9
# 184     jeUsbxROq0U                        9
# 185     bix2VdOd8sE                        9
# 186     -a9xOCei--s                        9
# 187     03vWXWG6uVk                        9
# 188     S5OGEXaaPus                        9
# 189     ZkaQ2F78CTU                        9
# 190     6JbBwRq56tQ                        9
# 191     gdcb1PUKr7k                        9
# 192     pRzeJtR-GdI                        9
# 193     wjeTU4weDj4                        9
# 194     -NbbIq20R-0                        9
# 195     8jW286eyvBk                        9
# 196     RbhehKTilO4                        9
# 197     EKZZr0ehunc                        9
# 198     bM3sr1kruC4                        9
# 199     GIu66mlrTHw                        9
# 200     sGOMAHOJxXM                        9
# 201     y8LIbeKQ60U                        9
# 202     IQBrumUogus                        9
# 203     bKImYZr9hgg                        9
# 204     4bIWfPEVZCA                        9
# 205     UH7PpLVy8-A                        9
# 206     27TzdWuPTVE                        9
# 207     x08pt9i5-AA                        9
# 208     toXurXvgr4E                        9
# 209     8bIjOaYB0yY                        9
# 210     7qDdINU6NWM                        9
# 211     9FDcAEL2lEg                        9
# 212     79ZlH6UbdF4                        9
# 213     432bWWRmiMA                        9
# 214     Hw0_1epMOfg                        9
# 215     n0GFf6OInSg                        9
# 216     MPYl3y3EWLQ                        9
# 217     U0bhE67HuDY                        9
# 218     hBxMx4sfw7o                        9
# 219     GkEP07xOaDQ                        9
# 220     eC-rcBlun20                        9
# 221     iVZIBc2JGC0                        9
# 222     KopwaDbed4s                        9
# 223     9tDZRogSbbU                        9
# 224     GhKWkhPW9GY                        9
# 225     J3ijs8_20rk                        9
# 226     tUhDTWPtqR4                        9
# 227     iF-ii0BoCuA                        9
# 228     N_X3lSUBLmM                        9
# 229     J3yBtinMNKY                        9
# 230     n7oMlrxkslk                        9
# 231     u_0iGULDZv4                        9
# 232     UGrGBojsSxU                        9
# 233     w0jPLftEpQI                        9
# 234     PZgRmNjIJ0s                        9
# 235     _RB8fn-IPsc                        9
# 236     T78EW8VxOaI                        9
# 237     1bKESS2XJLA                        9
# 238     quIjyB-a5FA                        9
# 239     JFpuNvDQzJI                        8
# 240     3LDHqNBga8U                        8
# 241     UQ35ivgm9gg                        8
# 242     lSP5kb5sp-A                        8
# 243     KSbitYtIXGE                        8
# 244     sZl1KWta78w                        8
# 245     etJu_iorwpc                        8
# 246     9U9GIc4-Izw                        8
# 247     v8aKFLYphms                        8
# 248     1laSm8RyQKs                        8
# 249     soWQlv8ZDys                        8
# 250     de-D6-rb-bo                        8
# 251     dpdfutEeHrw                        8
# 252     ZUXYAZn0NE4                        8
# 253     CdTX4KLR0sA                        8
# 254     9Pep6uJVptE                        8
# 255     b04EjrtWmPk                        8
# 256     cb9YJIBBOHk                        8
# 257     J9kVvkyUXr0                        8
# 258     PKqy_RxSCH4                        8
# 259     gjkazKjSrpw                        8
# 260     WciF9971XxI                        8
# 261     7B3HfhfZEcc                        8
# 262     XHaOWUONfus                        8
# 263     y1AZHY9oW-w                        8
# 264     r6LvP2t2MFY                        8
# 265     TTCQhMZgVxE                        8
# 266     DiIIQcT1dbI                        8
# 267     ykKy8cvgUDY                        8
# 268     _cYxHMadm3I                        8
# 269     xrAdHokTZUw                        8
# 270     GpraG9s0BDo                        8
# 271     U3TGS-1yGa4                        8
# 272     aE0Va4yKadg                        8
# 273     OuQKu03wCtI                        8
# 274     8Q7tyVFUaT4                        8
# 275     YY_sU2qKsQ0                        8
# 276     4V5smCXQGnI                        8
# 277     yEymIyLbiAI                        8
# 278     mY7ELHtlvZk                        8
# 279     vwY2OFy6Ph0                        8
# 280     _raSWBdVi-E                        8
# 281     r8rV_PEMPZM                        8
# 282     H8j8DSOTSBY                        8
# 283     5nG8QWmLj6A                        8
# 284     JVPz6q630Bw                        8
# 285     jQKWAfDjTBw                        8
# 286     DKoyoNUH8Ec                        8
# 287     _GopWa-UBBo                        8
# 288     ibByixBgiUw                        8
# 289     pRXmEi4ePbM                        8
# 290     kVJ_ni_c2V4                        8
# 291     prUOX8LhnmM                        8
# 292     -TXTz5Hmvvc                        8
# 293     AQVfFw1iH_4                        8
# 294     uOpuePds4UA                        8
# 295     CWfH0zr307Y                        8
# 296     ZSzkUwKDr8E                        8
# 297     1ESqTFz3QvU                        8
# 298     7oAComrlocI                        8
# 299     zPiCufnUrCM                        8
# 300     vN2bLydSAF8                        8
# 301     xH_D2_4z6P4                        8
# 302     _tnMKxchwCw                        8
# 303     bcH_cM1PFy8                        8
# 304     Pd5LgzJsoG8                        8
# 305     ZuhxPOfw5Hg                        8
# 306     aV_8wxerEtk                        8
# 307     k69OjrVucew                        8
# 308     RfIlKX7eVCg                        8
# 309     _fnhWl2Z-Gw                        8
# 310     wAYurJYRtNE                        8
# 311     FKoQ2IOxfZ4                        8
# 312     r2anU0cFQu4                        8
# 313     XBQb4z5I3Vk                        8
# 314     Q0upRWxstfw                        8
# 315     c3X2O6qKHcI                        8
# 316     Z1LeHynYZLk                        8
# 317     w4TuE-DK95E                        8
# 318     yzkmESADk2s                        8
# 319     wXdg3LAEmJo                        8
# 320     6hh7QafxMFY                        8
# 321     RRpwYD0uQzk                        8
# 322     S9p5yhE6_fk                        8
# 323     6tjtxQNcNLw                        8
# 324     tAN_qUgozBA                        8
# 325     8O_IvYybMK4                        8
# 326     q-GfD_jSktY                        8
# 327     IqBtABVsjDM                        8
# 328     gDMGaF8D0I8                        8
# 329     lSjEJYm-M6k                        8
# 330     ADrkMnFYRXc                        8
# 331     Q8casXtm4tk                        8
# 332     bI8fUDnz_-0                        8
# 333     poPSOShakUg                        8
# 334     UayYs0B2vas                        8
# 335     xkEHvK-q6fU                        8
# 336     ExkT9SW6cRI                        8
# 337     NOdfDosrnEg                        8
# 338     _lyy_vrFWh4                        8
# 339     3-OxUIzxovY                        8
# 340     Lbz1mqJn5Pg                        8
# 341     HeLfkw7Q1oc                        8
# 342     I5COzZlxaI4                        8
# 343     T_mhv2lwbjg                        8
# 344     yeHr0qshoto                        8
# 345     WTUpGTHGQKU                        8
# 346     FHr95BpjBBQ                        8
# 347     6CIw-vdd2ZI                        8
# 348     e8fWj6c0PuY                        8
# 349     UneNiZWcM-M                        8
# 350     nikWJyw0rxY                        8
# 351     NdjjbNZOij8                        8
# 352     Lf0UGsRnxcU                        8
# 353     PNrLXcXBVhk                        8
# 354     IM0qeZnlA5U                        8
# 355     xNI8gPEvQqk                        8
# 356     C4GsL45xF8M                        8
# 357     CgQFeQRVuSc                        8
# 358     4YM1sVYAKXU                        8
# 359     oxrv4iE2gbY                        8
# 360     X5zUC2bqWt4                        8
# 361     Xoz0WPcamCE                        8
# 362     mipZdU5kTrU                        8
# 363     UcZa7WhfLLg                        8
# 364     bae-xf0CQmg                        8
# 365     KnFGLQx2HO8                        8
# 366     IfgjHfB6NjA                        8
# 367     GjGZL6kWfhA                        8
# 368     mHLDm7RlGTQ                        8
# 369     hDosBjM4KzM                        8
# 370     A_jblzBBORo                        8
# 371     uJvbS1pi2Z4                        8
# 372     QjDAbic5aJE                        8
# 373     r830vDFWYDg                        8
# 374     J1dQRt0qJXY                        8
# 375     chbz_bqRqaI                        8
# 376     poGBUW5lV1E                        8
# 377     ISMBMDkY_eo                        8
# 378     G5O8MyExqUU                        8
# 379     uZ1ftWeCP3U                        8
# 380     2T3cAZX9_kE                        7
# 381     0BXP8GT3Fg4                        7
# 382     rRT4Tqx-NBk                        7
# 383     6ESYl2_LdDI                        7
# 384     FPyifXbD3sE                        7
# 385     9CLL1Na79lM                        7
# 386     oJvbsVSblfk                        7
# 387     pB4TnOBeK9M                        7
# 388     r3TIitcLTBA                        7
# 389     Tl8rcah4jkw                        7
# 390     McleQ90ancs                        7
# 391     2veTgJiGBOk                        7
# 392     RwiiNp6RjnA                        7
# 393     e2LBqIypQu4                        7
# 394     imaLiWVEVD8                        7
# 395     ZgIPrvEAZCg                        7
# 396     qttQk5nUg2k                        7
# 397     2KjJarihYgY                        7
# 398     MlJMVLNfDKo                        7
# 399     735TSFRyeUM                        7
# 400     D6DUSIww8ic                        7
# 401     bH91JK79l5k                        7
# 402     Xt7Cy9gNF9A                        7
# 403     sQMjKE5FeQk                        7
# 404     P2nN9ljc1_Q                        7
# 405     10OaFlPlVNM                        7
# 406     XVhC6sBg8BY                        7
# 407     hPCN8bC_IxE                        7
# 408     01oA5TVgOMY                        7
# 409     tPA_OMa2eVI                        7
# 410     91U9_q8LWPE                        7
# 411     p4wnvS9389A                        7
# 412     VYZeryPKcYs                        7
# 413     -02N9CyCvfs                        7
# 414     CPsT9viUi9M                        7
# 415     ElmpnJWOMkI                        7
# 416     1Hcuy3K6Z2M                        7
# 417     rjeKIeAUuwU                        7
# 418     0BUITssWi0M                        7
# 419     VO4LDgRoYdQ                        7
# 420     FlgHWcgW0M0                        7
# 421     jVcnKXo2GIQ                        7
# 422     zq5svb9jrjk                        7
# 423     ZU7huJzD9Ms                        7
# 424     HOu0jGMyzmw                        7
# 425     6ssvwmPy_9A                        7
# 426     3S2IsO141uE                        7
# 427     iJLHV1GCfIw                        7
# 428     qS8hh8_sGIs                        7
# 429     DxT8np064BA                        7
# 430     HVgZNfLX9Mc                        7
# 431     2X0-KeehZy4                        7
# 432     X3WpW-DJxX8                        7
# 433     C3iQIiFDyZw                        7
# 434     wShZbFJMffQ                        7
# 435     92r7s4FLt9U                        7
# 436     sOe4eCQ9aKg                        7
# 437     tJkGii9FH8g                        7
# 438     oqUzbxJrnPU                        7
# 439     u_FnvHW2ptQ                        7
# 440     tPauNwzAEwY                        7
# 441     rMljfWb0UwI                        7
# 442     qW0qbfllGpk                        7
# 443     FYLy-0Rx_kU                        7
# 444     m6rvSD9jNfg                        7
# 445     5uQIBNy5WaQ                        7
# 446     QPPym-VYj_4                        7
# 447     KxVwfPTGxgk                        7
# 448     XGBbKJmfzr0                        7
# 449     Uj3kb9OPLPQ                        7
# 450     LbCe28SvbDU                        7
# 451     PP4sz39lHG4                        7
# 452     8X4AHKB7MME                        7
# 453     mdwHQmlhLcQ                        7
# 454     CDL1IKyvmPY                        7
# 455     umv2jLqXXRo                        7
# 456     SU1oF4ca5C0                        7
# 457     guKgD5oRsPs                        7
# 458     t0FkwCBT7K8                        7
# 459     A88jagN1oKA                        7
# 460     jWexrdXkwvc                        7
# 461     azM8ehwt7Os                        7
# 462     RpI8y1ifv3Q                        7
# 463     zi9gYqyLF4Y                        7
# 464     vk9dDR1Nluk                        7
# 465     7jX_tFZV6KM                        7
# 466     HjBF23VxW0g                        7
# 467     VFGxAa0gLIo                        7
# 468     Tpbo25iBvfU                        7
# 469     gnq6W3FvIwo                        7
# 470     -qjRHUTsgjk                        7
# 471     uaG3arfzdP8                        7
# 472     BkQSCOYV8Tk                        7
# 473     oYsEhq8lEbk                        7
# 474     ot_3pjDHdhg                        7
# 475     gXH42YWb7qM                        7
# 476     Hx-0MwQtiyk                        7
# 477     f7_go-lXL8U                        7
# 478     qHmTaDKrKEM                        7
# 479     nj4qE_a-S_I                        7
# 480     ClXs1Ef2SKo                        7
# 481     HtU4M9T69AE                        7
# 482     cmQwYAdzUw8                        7
# 483     zuyEEpds5VE                        7
# 484     o_u21ZAAQuo                        7
# 485     R-ZVWyG4E3k                        7
# 486     OBnAFqE_RtY                        7
# 487     sttckqPbQhI                        7
# 488     FpoJg6lcLpM                        7
# 489     W4RVY6aq4dg                        7
# 490     yIBgJgBvga8                        7
# 491     vhMWIGW8qS4                        7
# 492     m7ytcpckusc                        7
# 493     YtwMO0mz6gM                        7
# 494     QedwLk_i6pc                        7
# 495     oyPcEuu_16A                        7
# 496     f7KgwkAmpqo                        7
# 497     xCOCjQnQ9z8                        7
# 498     QZ7jFayG8Z0                        7
# 499     dwkgJz5viQ4                        7
# 500     jpfwFEiHH50                        7
# 501     OpGmRFsRbpE                        7
# 502     8kAg-xS7MN4                        7
# 503     15Apm3Layow                        7
# 504     R65MRN0QUE8                        7
# 505     4Abttt1HTvk                        7
# 506     gzbdFkHDr2w                        7
# 507     23PNskHQVFQ                        7
# 508     88kQzuyaP1w                        7
# 509     LYm45LPQbw0                        7
# 510     JcO5qydAM_g                        7
# 511     ZrsMjRqF8dA                        7
# 512     DEwNCyuUjvw                        7
# 513     waxxdikgDAs                        7
# 514     JmCk8Q8qRn0                        7
# 515     Bib1bO3Xm3g                        7
# 516     SKY1o91q3y0                        7
# 517     GaM2VlsmDJc                        7
# 518     IszZL4t7AUg                        7
# 519     rcKbOVI_yBo                        7
# 520     UpeIH8cnhPw                        7
# 521     IQYQEvhJG6E                        7
# 522     Xv6ir-A2j04                        7
# 523     Uumx6I64Hr8                        7
# 524     aFroMxjzIqg                        7
# 525     68mHiEMuPxA                        7
# 526     A5KReLimUUo                        7
# 527     eWR4qfP6K3Y                        7
# 528     VqYrjs0zgU0                        7
# 529     O98yAr5Spa4                        7
# 530     ElSyPQVvO1c                        7
# 531     zGV0y8BTA0Q                        7
# 532     cv2VUQpgUss                        7
# 533     _QuKP0rEtnU                        7
# 534     vfCXG2axLmw                        7
# 535     oIp-bQrGZ0M                        7
# 536     Ejn00Mh7KKQ                        7
# 537     g6-QLBGPpoU                        7
# 538     VAUFmWj85Os                        7
# 539     a9PNQtuKqxU                        7
# 540     8pTy5gVYcGQ                        7
# 541     VIvcGzXOMIU                        7
# 542     zqtbVOnnT_A                        7
# 543     D5xWN7WP-pU                        7
# 544     l2gzM0xdHNo                        7
# 545     HDkCwjd5xwM                        7
# 546     dNIz22MlM_Y                        7
# 547     3M_jald7Vlw                        7
# 548     QERqsoJTgYE                        7
# 549     SrgquwNy5iA                        7
# 550     zXpkv21rguE                        7
# 551     GEVifYTYDcw                        7
# 552     jOCmKLT24ZE                        7
# 553     Cz4yJQKIxSk                        7
# 554     WMABvhVyrs4                        7
# 555     ocWjGpBrTjg                        7
# 556     -O2VKm_CcXo                        7
# 557     18NEJPo-PIc                        7
# 558     R3W0HRuI6sI                        7
# 559     IFCsoNGs0A8                        7
# 560     _RRG9moUqhw                        7
# 561     n3850aMm6vo                        7
# 562     q8nX91GxLBU                        7
# 563     BmqGE6SX8Ps                        7
# 564     EukUdde7WK8                        7
# 565     5nwUccNxl2Q                        7
# 566     3eOEqeff18U                        7
# 567     O_ubOzGnmuM                        7
# 568     ulRhtLSGR4E                        7
# 569     se4cgbBhOwg                        7
# 570     dLBW15rG1WQ                        7
# 571     b8UrXs3-oXs                        7
# 572     mkS3LVUKBIo                        7
# 573     KGYyQqgFjYI                        7
# 574     L6g-qrHSSoQ                        7
# 575     N9r-6v0kxaE                        7
# 576     QO1EWD205cY                        7
# 577     SL9BmuBauR0                        7
# 578     W0N7E4wfjf4                        7
# 579     K6B1yIDM4wY                        7
# 580     HVfH8x6ih6E                        7
# 581     MMEJ_NatkFs                        7
# 582     Ef9xOwKo9Fs                        7
# 583     s-klpkVWans                        7
# 584     4LG9wQpMTTk                        7
# 585     kJIUPm3ECH8                        7
# 586     cP3AQ37XC5Q                        7
# 587     N76y8yJBsBA                        7
# 588     CiFOsVye6IE                        7
# 589     lY2-9AtPdr4                        7
# 590     bkw3GmCuIu0                        7
# 591     CvNUdJaazO0                        7
# 592     RltPN8e3kMs                        7
# 593     opojLnLLf3g                        7
# 594     KgxSwkWKS-U                        7
# 595     fiAcNGGG4Jk                        7
# 596     RG71OxOoqEM                        7
# 597     dGd5T6Ewe-w                        7
# 598     BtuTzB_2HcE                        7
# 599     yd6ISKQ0fTE                        7
# 600     rHW9y8jebGk                        7
# 601     738fwFERIUQ                        7
# 602     EIJQsE8C5Is                        7
# 603     v36-w8HI0o0                        7
# 604     H14346aHrk4                        7
# 605     j0opbk6EYIE                        7
# 606     aFR4ZqJ3JBQ                        7
# 607     OCKcWFdO4TI                        7
# 608     CeLC6jqcRZQ                        7
# 609     WjwknsaHIqs                        7
# 610     Rd-UJgJLrtw                        7
# 611     YO3wdtnWGXk                        7
# 612     lqMXHvxxRkQ                        7
# 613     HRDw_PntqkU                        7
# 614     04BYEugkQfA                        7
# 615     6FoPpKNYjTE                        7
# 616     So0L5jZnWZ4                        7
# 617     XJx2Vd5P5K8                        7
# 618     ZU0KHDzBn44                        7
# 619     W9OFSkOlqxA                        7
# 620     hcAM69dhawM                        7
# 621     ib4UmVJW8Tk                        7
# 622     ZlFEH1xNZ6Y                        7
# 623     X1Xv1tGTgbE                        7
# 624     T3rFOauwJDg                        7
# 625     jpRMG9-YDWM                        7
# 626     exzyw4daiv8                        7
# 627     1dpLMNI8AaM                        7
# 628     whPL2gNTIic                        7
# 629     SIWDngGeyeE                        7
# 630     NMZ-H6wWI6c                        7
# 631     TbS4WSvmBNk                        7
# 632     5d-3NvTWzM8                        7
# 633     jDRHFaHHXDQ                        7
# 634     f1vSHauv1VY                        7
# 635     BqNmuyYHrGo                        7
# 636     UUST4fVX6fM                        7
# 637     PFxhbbonz5g                        7
# 638     e3F6_ZuFTvI                        7
# 639     bCM0d1x84fA                        7
# 640     kIR6eFbma9A                        7
# 641     Cdhxm7BZvAg                        7
# 642     OWCEii7HvGE                        7
# 643     SIqJ381dXwk                        7
# 644     sZ8rSqtwZp0                        7
# 645     lEb2k51RFYo                        7
# 646     wOZUwJvYZuE                        7
# 647     awZtGPXYWgA                        7
# 648     2fWDwFAmbCo                        7
# 649     C4PL41UOUzg                        7
# 650     _2txvnq2riU                        7
# 651     RnRchqwohLo                        7
# 652     LYTCt7LOtDM                        7
# 653     iv-jM14_NTI                        7
# 654     oZjjkOgwrEs                        7
# 655     0BOzdhC4WJs                        7
# 656     MYZAxytHDIU                        7
# 657     qTcuU_Nz6sw                        7
# 658     9jIiLWt95wA                        7
# 659     eAqActLRr-M                        7
# 660     0IJWdCanKHU                        7
# 661     CDawUfjTePQ                        7
# 662     G3HJdoUsKKM                        7
# 663     JfGch8dZUks                        7
# 664     9YwMctQtYnQ                        7
# 665     6wiXYIN8oGw                        7
# 666     PqQ0XNAiWtk                        7
# 667     WGc_bUdCwNE                        7
# 668     spxZSuQLD9Q                        7
# 669     bazH-CKjk-4                        7
# 670     FHl0N48KaIc                        7
# 671     6vU0ViZ-vRw                        7
# 672     N_970kHEBsY                        7
# 673     tbr4CIjpcqc                        7
# 674     JY9u7n8Hiv0                        7
# 675     mG9g8gqZ6Yw                        7
# 676     4kIPRWImnXQ                        7
# 677     P_SDZE24qJc                        7
# 678     VUG7m-IyoZ8                        7
# 679     idHa_ABJ8io                        7
# 680     iu5qiCKVp5w                        7
# 681     DgaU1ILaF7I                        7
# 682     u4hDpWrkhyg                        7
# 683     pgNNx2mQFk8                        7
# 684     77y18-LQib4                        7
# 685     7KmoqUVZ-KE                        7
# 686     NY84pwc7Hs0                        7
# 687     6uPj2JueWaw                        7
# 688     FgU4IYe5YzY                        7
# 689     0VN1vfnMC8s                        7
# 690     4peRy2vx7Wo                        7
# 691     hL7-745x-dg                        7
# 692     XdBgzpysBF8                        7
# 693     Jez6pmpHLEw                        7
# 694     9_15GNk_PDo                        7
# 695     VAkbTYAjs3U                        7
# 696     dmD2mUWVeiY                        7
# 697     KrhhWaNcWI8                        7
# 698     6NQNHDgMsmE                        7
# 699     PByPOjcvot0                        7
# 700     ny2tvTBeNu8                        6
# 701     _S92-wZ_tfM                        6
# 702     JS76D7JOR5Y                        6
# 703     gzAE2AClYQE                        6
# 704     SrCSI73f0GY                        6
# 705     7RVPz4Ab_v4                        6
# 706     XH69w6VFPYc                        6
# 707     IMKYVe5gloc                        6
# 708     Aj9LJDWQHjM                        6
# 709     sxCvE7A8htA                        6
# 710     x7sW9_242nA                        6
# 711     87EzOx4yt7w                        6
# 712     v7WYpj3JwV0                        6
# 713     CD0W_x029EE                        6
# 714     koh9vY-SdCQ                        6
# 715     IHp7JinIC6Q                        6
# 716     bFdyfnLSots                        6
# 717     8MFCzziQaBI                        6
# 718     gKQ_fY7zgzw                        6
# 719     Oq7FK5OYq7I                        6
# 720     3uqASw5aKrM                        6
# 721     9nahRQUcRHE                        6
# 722     QlzQam4yTpg                        6
# 723     AQuEBnnzNUc                        6
# 724     XuqvIOuWAPU                        6
# 725     Pm1KWH7Nrag                        6
# 726     shlbPsrxoag                        6
# 727     OJH5xdeF_KI                        6
# 728     1kKh-eTTZMw                        6
# 729     yXJk952GiyU                        6
# 730     y8gLwvT2e8U                        6
# 731     n7Y6qwZp3Mo                        6
# 732     I3Qgwg0erhQ                        6
# 733     zAZQC7VfLUM                        6
# 734     FZX5ssy1Fm4                        6
# 735     e5aIUjVYV1I                        6
# 736     C0Ssw8egWc8                        6
# 737     M2neIKEyU3I                        6
# 738     hh4hj_HL-ws                        6
# 739     7cgjPl9O-hQ                        6
# 740     FLEpQJAEDz0                        6
# 741     6BnYPD44YCw                        6
# 742     dyqL14qfW4U                        6
# 743     vBBwowf4sd4                        6
# 744     jLlixoCruWU                        6
# 745     ixiRIZxojWc                        6
# 746     pRCZnRMGdEE                        6
# 747     uEPiK1mSqAU                        6
# 748     cFFypfUWTJQ                        6
# 749     Ty7ldm0hOtM                        6
# 750     XKZqDaaBjpk                        6
# 751     TUK8-SaHn1g                        6
# 752     bnW18ntaP9I                        6
# 753     nC-2wUBLPtk                        6
# 754     w_oaK2I8dT0                        6
# 755     PfENVB9epnE                        6
# 756     6hy1Vp-R4to                        6
# 757     ZHiljm-1FK4                        6
# 758     o98lkE5HW3g                        6
# 759     _0TsRzZg3cQ                        6
# 760     BKcv0V3hoSY                        6
# 761     KODdcKdaXRM                        6
# 762     cjx_e5Vwez0                        6
# 763     qe4ieDMZzFI                        6
# 764     fP5wa3Cp5sg                        6
# 765     KOSIeZ2gd6k                        6
# 766     AdNaC36G5-o                        6
# 767     zoHt7LfnK7k                        6
# 768     ybAw3oeSDNk                        6
# 769     fMzX7WThBLM                        6
# 770     QUjR7pJDFuk                        6
# 771     uPulS_kPL6w                        6
# 772     aM-drdmzSf4                        6
# 773     qlEVzjJZhwI                        6
# 774     eDNVhGXcHPo                        6
# 775     4deZYYdtfis                        6
# 776     -MeJxjqi4bE                        6
# 777     cV1ZN7ks6MY                        6
# 778     H0rmD0Rw3n4                        6
# 779     jiQj4fpGCQQ                        6
# 780     AHR-7ywsowA                        6
# 781     t8833MiX4qY                        6
# 782     NeeQ1tGuAvE                        6
# 783     hAgFYGsCrvM                        6
# 784     nRxgAcZdm60                        6
# 785     AFWBn2jqYt4                        6
# 786     4AFDFEO0YXs                        6
# 787     nDvMxuT6EVg                        6
# 788     s02T_WbiCa8                        6
# 789     uBNFfCyYZU0                        6
# 790     vbfQ1JSeRBg                        6
# 791     hyUlyU8_pBk                        6
# 792     iYWHk0Y5WyY                        6
# 793     uqLbZRAB_bY                        6
# 794     sdrTKklbex0                        6
# 795     bsE1iA48Wis                        6
# 796     eJ8-5vMtI3A                        6
# 797     0YUF7xIZYIc                        6
# 798     BaaWIrJbJFw                        6
# 799     NMVqmbfgsLo                        6
# 800     Q3FblO6sXN0                        6
# 801     WMnqjdaSjms                        6
# 802     V3k0WTfzisw                        6
# 803     YYqnTNT7FxQ                        6
# 804     VnOC9iizThk                        6
# 805     HwTrnZ-BWe0                        6
# 806     loXmF8G_RpE                        6
# 807     geOtjvYMa6M                        6
# 808     2CYF6qnUXQA                        6
# 809     aXrQQ7EvGcA                        6
# 810     nYRUoSvzfmc                        6
# 811     EsKT6EC-zl0                        6
# 812     yhzN3T0Qbl0                        6
# 813     qDztofyKkt4                        6
# 814     V2r3SmHQJss                        6
# 815     ysGS0RmtoU8                        6
# 816     ujQ5eEUMkuc                        6
# 817     WkYjDIGbdSc                        6
# 818     1Pc-NizMgg8                        6
# 819     y7TUQjAltDI                        6
# 820     t3w2pkxC_P4                        6
# 821     OxaYVCegOOY                        6
# 822     6zVGLkZJbHU                        6
# 823     ds7X7HuM6Zo                        6
# 824     2PpsVfgb-jg                        6
# 825     2sQ5jXUKwp8                        6
# 826     IoyTBVzYxY0                        6
# 827     lNfwikGiNn8                        6
# 828     Px8AQK32zgc                        6
# 829     4k1WgqLV5Sk                        6
# 830     9r7o0ery8VE                        6
# 831     6OvY8mv5f48                        6
# 832     raDAe82MYpI                        6
# 833     kIrYBRsUpVM                        6
# 834     vgkGfymvt8Q                        6
# 835     3rANYS6Ckbg                        6
# 836     chhNiQ8ZLlk                        6
# 837     YvUW33pctKA                        6
# 838     UzCVcZFq3XA                        6
# 839     ZWKRyL_7hcI                        6
# 840     sInijI1vr34                        6
# 841     FY8CPH7UM2I                        6
# 842     kcoHbMJ8U34                        6
# 843     LLYStFR5QmY                        6
# 844     -GCTuXWNpCM                        6
# 845     rMiiMk0ZPCQ                        6
# 846     LWJRqX5qSow                        6
# 847     TDg3pEah-Gc                        6
# 848     jUkF6QSF7g8                        6
# 849     oIPTaG8cxTw                        6
# 850     Y_MeyccjH08                        6
# 851     bFOgWaNuYGg                        6
# 852     qGVUBq5jzZg                        6
# 853     zeNlBdg0fq4                        6
# 854     rtHekS2B5UY                        6
# 855     C4fbOGxiFDc                        6
# 856     Eod-1KE0wqY                        6
# 857     x9DFscQOal0                        6
# 858     iacHuRtitOE                        6
# 859     mFeoeJoZeJE                        6
# 860     jmd5_rfb-Vg                        6
# 861     iB5HSxNYpCY                        6
# 862     Y4A4l1rJUmA                        6
# 863     yveaPwKuRp8                        6
# 864     sVgAwUTJdCg                        6
# 865     f9jRRTB_STA                        6
# 866     MCsfC-5ER7Q                        6
# 867     nT9d99wagH4                        6
# 868     LIbKVpBQKJI                        6
# 869     ZUv7bmi45t4                        6
# 870     TZ7ZFitKKYs                        6
# 871     w5qRx68Qnrs                        6
# 872     8-HeS2DXVAc                        6
# 873     m6zklGhMjLY                        6
# 874     J4urUPURsW8                        6
# 875     _DPgFoDiTvY                        6
# 876     BuZdeldVDXA                        6
# 877     76o-9alHp4A                        6
# 878     C2ytbSa3mPg                        6
# 879     6a0CceZrT9I                        6
# 880     jIcb2-oGmJg                        6
# 881     Cc0VwlS-Tvs                        6
# 882     bil2fAQ36dY                        6
# 883     -RbE0ot6bsg                        6
# 884     y3Pcp75oB74                        6
# 885     RoIGaPGrXvo                        6
# 886     EjOvRl4SoqY                        6
# 887     eyu7qabVmWI                        6
# 888     1bA4I2QSuCE                        6
# 889     IS4mFAcg6jE                        6
# 890     qjxRLQlrY_U                        6
# 891     ooMeO0sj0C8                        6
# 892     A6fGF3Rn6z4                        6
# 893     2h2iZl8Yx7c                        6
# 894     KxDIBYGPAiM                        6
# 895     MxFaaL6BZP0                        6
# 896     1OBbQ4qhLXQ                        6
# 897     zd6QHaeOrNg                        6
# 898     oRYhzrZ8G_Y                        6
# 899     whIRkuTQerU                        6
# 900     gNMGc2SiBjQ                        6
# 901     v0qwIjTmiHk                        6
# 902     4E-vOLCBtZQ                        6
# 903     IqrtZnGWEIA                        6
# 904     QHoRNDcXV5U                        6
# 905     iq1IqV_RiCk                        6
# 906     bSZj19AUU5I                        6
# 907     PNBo7E-D8RA                        6
# 908     IpX76RU1_OI                        6
# 909     CXa6cZfTB2c                        6
# 910     3TGkpUj5AX4                        6
# 911     xiIyiFG8qwI                        6
# 912     7ibgq3yoXqM                        6
# 913     gACa1rOAJo8                        6
# 914     OnxXrg8Xf4c                        6
# 915     qC8QXuATZFg                        6
# 916     zcJHIaREg6A                        6
# 917     spGgqGT8W00                        6
# 918     S651_oLl9rw                        6
# 919     QNT47KPW1fE                        6
# 920     -jbj4wC5lQQ                        6
# 921     3Wt7f9GsjNc                        6
# 922     9ECNjeRWERw                        6
# 923     nKP-DuyxZ1Y                        6
# 924     PnEbCrl30P0                        6
# 925     JuiYnTdNrJo                        6
# 926     KcNPV-cvIx4                        6
# 927     FCn7U5TT09o                        6
# 928     hInQnxhJoqg                        6
# 929     uln2p08-SUU                        6
# 930     6VIqBorVkZA                        6
# 931     kPagAKT_zhQ                        6
# 932     dw-fS-FzIOI                        6
# 933     E_qLMOf9lDs                        6
# 934     JGwSZb4oPMw                        6
# 935     Ltv2nchhdaw                        6
# 936     pEYCNHNcXN0                        6
# 937     -xGmdwJAibU                        6
# 938     bvgl_xOpTrw                        6
# 939     EXpkv33rJbc                        6
# 940     HZurNDgaYpI                        6
# 941     Ra1f5gZYrco                        6
# 942     o-tALExbJ6k                        6
# 943     MYaNEFj5-hY                        6
# 944     pV45CNSq59E                        6
# 945     YVAUigMkW9g                        6
# 946     RiOZHpPd2v8                        6
# 947     Kj8epxTiNXc                        6
# 948     lrt4QxHfPJE                        6
# 949     DS6fGfZZgV4                        6
# 950     pW8As9P_q84                        6
# 951     DWGtZ4Y3pCw                        6
# 952     MMbtwJk7-Ys                        6
# 953     OLUkj1At-GQ                        6
# 954     Ey72vmp5z-U                        6
# 955     5aBX6xheIzA                        6
# 956     RBQc_NsooAQ                        6
# 957     bS55PcbI61s                        6
# 958     akJzCX_KUws                        6
# 959     Q6Y3T80C4oY                        6
# 960     oTNSIkBkrNc                        6
# 961     2XmkE6OUrUM                        6
# 962     SdxAtq0Wukk                        6
# 963     jlxT4YSE4XU                        6
# 964     yG_0JIFoWzo                        6
# 965     Fs3U4B15osE                        6
# 966     BEGRUifzQUM                        6
# 967     dZBVPWGPKvE                        6
# 968     b2qgiw2LP_Y                        6
# 969     SJHs4V1OUYU                        6
# 970     Q6VKbabN9O4                        6
# 971     NNUSL304hvI                        6
# 972     vtqXZkXdbus                        6
# 973     JVPoke8AgcE                        6
# 974     XINF1rOlrPE                        6
# 975     1rmesmC6wDk                        6
# 976     3ekbENtRo4Q                        6
# 977     fgYJkmxCW50                        6
# 978     m0W0M_SP8Mc                        6
# 979     TCeaIA1jr7U                        6
# 980     -CTn7CP8kj8                        6
# 981     biSlFmOQWWs                        6
# 982     eCP4MvhkuXI                        6
# 983     pndrvBzyi3s                        6
# 984     DMg6KdUlZZg                        6
# 985     bBoMd2O_bmI                        6
# 986     4K8871MRlVk                        6
# 987     d9CMvd94-AM                        6
# 988     3EwjSPM3bIk                        6
# 989     BbhmLagu9FI                        6
# 990     NaL2vUe7Pls                        6
# 991     iAKGHCHMg9g                        6
# 992     zj4nR81ORGc                        6
# 993     aFfoUe850Co                        6
# 994     vywo24hrgsc                        6
# 995     CKnZU2ocXRk                        6
# 996     587hxDk9Ay4                        6
# 997     x6uoKPEI4RQ                        6
# 998     U1HuRBW6jU0                        6
# 999     WCFnZyEwo1c                        6
# 1000    PAihmmFHXGM                        6
# 1001    h_0cWWYj-24                        6
# 1002    zJiNkOQ_vAM                        6
# 1003    O--TtEgiJ9Q                        6
# 1004    isdfF2qk5Qw                        6
# 1005    sJlT7Uhox30                        6
# 1006    pEjXfP_emK8                        6
# 1007    nirKaVVEuG8                        6
# 1008    _Te2a6thTjk                        6
# 1009    -l1c4seJRHc                        6
# 1010    8uQh3xx6c38                        6
# 1011    LV-nRlRlKwc                        6
# 1012    uFEuxnIkfyU                        6
# 165405  Mc2FmCTF3iA                        1
# 165406  Plp0btYBnzE                        1
# 165407  _8orqS6TGcw                        1
# 165408  KiwUXlY-K1w                        1
# 165409  5QeopdSpSpE                        1
# 165410  AmnQJCuCQqI                        1
# 165411  E2X_E6ngdTg                        1
# 165412  5sLeLo084mg                        1
# 165413  PVQZ1_67ay8                        1
# 165414  WPCE8lJtasc                        1
# 165415  _3m0T_WCFrc                        1
# 165416  ShORXkDNAYI                        1
# 165417  mRP2m7H9gCY                        1
# 165418  sOG_eWOp6g8                        1
# 165419  IjTSeCyYkKc                        1
#
# [165420 rows x 2 columns]

# %% [markdown]
# Merge freqeuncy of vid in playlist into main dataframe

# %%
data = pd.merge(data, videoId_list, how='left', on='videoId')
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount  stats_commentCount stats_hiddenSubscriberCount  stats_subscriberCount  stats_videoCount  \
# 0   243100.0                   0                       False                7860308               894
# 1    38640.0                   0                       False                7860308               894
#
#    stats_viewCount  num_of_playlists  num_of_playlists_forvid
# 0       1523479095                17                      1.0
# 1       1523479095                17                      NaN

# %%
#save as csv
filename=str(name)+'_Final.csv'
data.to_csv(filename)
data=pd.read_csv(filename)
del data['Unnamed: 0']
data.head(2)
# Out:
#         dateDownloaded                 channelId channelTitle           kind      videoId  \
# 0  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  Pb8RAH4ywNY
# 1  2018-02-17T15:32:34  UC4rlAVgAK0SGk-yTfe48Qpw  BRIGHT SIDE  youtube#video  v2g9xuJynVY
#
#                                            title                                        description  \
# 0  10 Signs You're STUCK in a Toxic Relationship  Subscribe to Bright Side : https://goo.gl/rQTJ...
# 1          8 Tricks Bosses Use to Steal Your Pay  Subscribe to Bright Side : https://goo.gl/rQTJ...
#
#                 publishedAt  vidfrequency  vidtype  categoryId videoDuration  commentCount  dislikeCount  likeCount  \
# 0  2017-06-29T17:00:02.000Z           110       26          26       PT5M47S         560.0         228.0     5101.0
# 1  2017-06-29T11:00:05.000Z           110       26          26       PT7M37S          77.0          67.0     1007.0
#
#    viewCount  stats_commentCount stats_hiddenSubscriberCount  stats_subscriberCount  stats_videoCount  \
# 0   243100.0                   0                       False                7860308               894
# 1    38640.0                   0                       False                7860308               894
#
#    stats_viewCount  num_of_playlists  num_of_playlists_forvid
# 0       1523479095                17                      1.0
# 1       1523479095                17                      NaN
